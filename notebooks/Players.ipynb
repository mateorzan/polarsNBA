# %% [markdown]
# # DATASET SACADO DE KAGGLE (https://www.kaggle.com/datasets/eoinamoore/historical-nba-data-and-player-box-scores)

# %%
# Librerías
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.getcwd()

# Configurar visualización amplia 
pl.Config.set_tbl_cols(-1)
pl.Config.set_tbl_width_chars(300)
pl.Config.set_fmt_str_lengths(150)
pl.Config.set_tbl_rows(10)
# Out:
# polars.config.Config

# %% [markdown]
# ### Cargamos el Dataset como LazyFrame

# %%
# Install dependencies as needed:
# pip install kagglehub[polars-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "Players.csv"

# Load the latest version
lf = kagglehub.load_dataset(
  KaggleDatasetAdapter.POLARS,
  "eoinamoore/historical-nba-data-and-player-box-scores",
  file_path,
)

print("First 5 records:", lf.collect().head())
# Out:
# /tmp/ipykernel_659204/1947884339.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   lf = kagglehub.load_dataset(
# First 5 records: shape: (5, 14)
# ┌───────────┬───────────┬──────────────┬───────────┬─────────────────┬─────────┬──────────────┬───────────────┬───────┬─────────┬────────┬───────────┬────────────┬─────────────┐
# │ personId  ┆ firstName ┆ lastName     ┆ birthDate ┆ school          ┆ country ┆ heightInches ┆ bodyWeightLbs ┆ guard ┆ forward ┆ center ┆ draftYear ┆ draftRound ┆ draftNumber │
# │ ---       ┆ ---       ┆ ---          ┆ ---       ┆ ---             ┆ ---     ┆ ---          ┆ ---           ┆ ---   ┆ ---     ┆ ---    ┆ ---       ┆ ---        ┆ ---         │
# │ i64       ┆ str       ┆ str          ┆ str       ┆ str             ┆ str     ┆ i64          ┆ i64           ┆ str   ┆ str     ┆ str    ┆ i64       ┆ i64        ┆ i64         │
# ╞═══════════╪═══════════╪══════════════╪═══════════╪═════════════════╪═════════╪══════════════╪═══════════════╪═══════╪═════════╪════════╪═══════════╪════════════╪═════════════╡
# │ 196294534 ┆ Alberto   ┆ Abalde       ┆ null      ┆ null            ┆ null    ┆ null         ┆ null          ┆ null  ┆ null    ┆ null   ┆ null      ┆ null       ┆ null        │
# │ 76001     ┆ Alaa      ┆ Abdelnaby    ┆ null      ┆ Duke            ┆ USA     ┆ 82           ┆ 240           ┆ 0     ┆ 1       ┆ 0      ┆ 1990      ┆ 1          ┆ 25          │
# │ 76002     ┆ Zaid      ┆ Abdul-Aziz   ┆ null      ┆ Iowa State      ┆ USA     ┆ 81           ┆ 235           ┆ 0     ┆ 0       ┆ 1      ┆ 1968      ┆ 1          ┆ 5           │
# │ 76003     ┆ Kareem    ┆ Abdul-Jabbar ┆ null      ┆ UCLA            ┆ USA     ┆ 86           ┆ 225           ┆ 0     ┆ 0       ┆ 1      ┆ 1969      ┆ 1          ┆ 1           │
# │ 51        ┆ Mahmoud   ┆ Abdul-Rauf   ┆ null      ┆ Louisiana State ┆ USA     ┆ 73           ┆ 162           ┆ 1     ┆ 0       ┆ 0      ┆ 1990      ┆ 1          ┆ 3           │
# └───────────┴───────────┴──────────────┴───────────┴─────────────────┴─────────┴──────────────┴───────────────┴───────┴─────────┴────────┴───────────┴────────────┴─────────────┘

# %% [markdown]
# ### Analisis de Datos

# %%
# Visualizamos los datos con LazyFrame
lf.collect()
# Out:
# shape: (6_683, 14)
# ┌────────────┬──────────────┬──────────────┬───────────┬─────────────────┬─────────┬──────────────┬───────────────┬───────┬─────────┬────────┬───────────┬────────────┬─────────────┐
# │ personId   ┆ firstName    ┆ lastName     ┆ birthDate ┆ school          ┆ country ┆ heightInches ┆ bodyWeightLbs ┆ guard ┆ forward ┆ center ┆ draftYear ┆ draftRound ┆ draftNumber │
# │ ---        ┆ ---          ┆ ---          ┆ ---       ┆ ---             ┆ ---     ┆ ---          ┆ ---           ┆ ---   ┆ ---     ┆ ---    ┆ ---       ┆ ---        ┆ ---         │
# │ i64        ┆ str          ┆ str          ┆ str       ┆ str             ┆ str     ┆ i64          ┆ i64           ┆ str   ┆ str     ┆ str    ┆ i64       ┆ i64        ┆ i64         │
# ╞════════════╪══════════════╪══════════════╪═══════════╪═════════════════╪═════════╪══════════════╪═══════════════╪═══════╪═════════╪════════╪═══════════╪════════════╪═════════════╡
# │ 196294534  ┆ Alberto      ┆ Abalde       ┆ null      ┆ null            ┆ null    ┆ null         ┆ null          ┆ null  ┆ null    ┆ null   ┆ null      ┆ null       ┆ null        │
# │ 76001      ┆ Alaa         ┆ Abdelnaby    ┆ null      ┆ Duke            ┆ USA     ┆ 82           ┆ 240           ┆ 0     ┆ 1       ┆ 0      ┆ 1990      ┆ 1          ┆ 25          │
# │ 76002      ┆ Zaid         ┆ Abdul-Aziz   ┆ null      ┆ Iowa State      ┆ USA     ┆ 81           ┆ 235           ┆ 0     ┆ 0       ┆ 1      ┆ 1968      ┆ 1          ┆ 5           │
# │ 76003      ┆ Kareem       ┆ Abdul-Jabbar ┆ null      ┆ UCLA            ┆ USA     ┆ 86           ┆ 225           ┆ 0     ┆ 0       ┆ 1      ┆ 1969      ┆ 1          ┆ 1           │
# │ 51         ┆ Mahmoud      ┆ Abdul-Rauf   ┆ null      ┆ Louisiana State ┆ USA     ┆ 73           ┆ 162           ┆ 1     ┆ 0       ┆ 0      ┆ 1990      ┆ 1          ┆ 3           │
# │ …          ┆ …            ┆ …            ┆ …         ┆ …               ┆ …       ┆ …            ┆ …             ┆ …     ┆ …       ┆ …      ┆ …         ┆ …          ┆ …           │
# │ 1962936150 ┆ Maurillioh   ┆ de Rosa      ┆ null      ┆ null            ┆ null    ┆ null         ┆ null          ┆ null  ┆ null    ┆ null   ┆ null      ┆ null       ┆ null        │
# │ 560        ┆ de la Fuente ┆ de la Fuente ┆ null      ┆ null            ┆ null    ┆ null         ┆ null          ┆ null  ┆ null    ┆ null   ┆ null      ┆ null       ┆ null        │
# │ 1642365    ┆ Nikola       ┆ Đurisic      ┆ null      ┆ Mega Basket     ┆ Belgium ┆ 80           ┆ 214           ┆ 1     ┆ 0       ┆ 0      ┆ 2024      ┆ 2          ┆ 43          │
# │ 196294611  ┆ Olivinha     ┆ null         ┆ null      ┆ null            ┆ null    ┆ null         ┆ null          ┆ null  ┆ null    ┆ null   ┆ null      ┆ null       ┆ null        │
# │ 43217      ┆ Olivinha     ┆ null         ┆ null      ┆ null            ┆ null    ┆ null         ┆ null          ┆ null  ┆ null    ┆ null   ┆ null      ┆ null       ┆ null        │
# └────────────┴──────────────┴──────────────┴───────────┴─────────────────┴─────────┴──────────────┴───────────────┴───────┴─────────┴────────┴───────────┴────────────┴─────────────┘

# %%
lf.schema
# Out:
# /tmp/ipykernel_659204/2177650233.py:1: PerformanceWarning: Resolving the schema of a LazyFrame is a potentially expensive operation. Use `LazyFrame.collect_schema()` to get the schema without this warning.
#   lf.schema
# Schema([('personId', Int64),
#         ('firstName', String),
#         ('lastName', String),
#         ('birthDate', String),
#         ('school', String),
#         ('country', String),
#         ('heightInches', Int64),
#         ('bodyWeightLbs', Int64),
#         ('guard', String),
#         ('forward', String),
#         ('center', String),
#         ('draftYear', Int64),
#         ('draftRound', Int64),
#         ('draftNumber', Int64)])

# %%
lf.describe()
# Out:
# shape: (9, 15)
# ┌────────────┬────────────┬──────────────┬──────────┬───────────┬─────────────────────────────────────┬───────────┬──────────────┬───────────────┬───────┬─────────┬────────┬─────────────┬────────────┬─────────────┐
# │ statistic  ┆ personId   ┆ firstName    ┆ lastName ┆ birthDate ┆ school                              ┆ country   ┆ heightInches ┆ bodyWeightLbs ┆ guard ┆ forward ┆ center ┆ draftYear   ┆ draftRound ┆ draftNumber │
# │ ---        ┆ ---        ┆ ---          ┆ ---      ┆ ---       ┆ ---                                 ┆ ---       ┆ ---          ┆ ---           ┆ ---   ┆ ---     ┆ ---    ┆ ---         ┆ ---        ┆ ---         │
# │ str        ┆ f64        ┆ str          ┆ str      ┆ str       ┆ str                                 ┆ str       ┆ f64          ┆ f64           ┆ str   ┆ str     ┆ str    ┆ f64         ┆ f64        ┆ f64         │
# ╞════════════╪════════════╪══════════════╪══════════╪═══════════╪═════════════════════════════════════╪═══════════╪══════════════╪═══════════════╪═══════╪═════════╪════════╪═════════════╪════════════╪═════════════╡
# │ count      ┆ 6683.0     ┆ 6682         ┆ 6681     ┆ 0         ┆ 4617                                ┆ 4727      ┆ 4570.0       ┆ 4564.0        ┆ 5036  ┆ 5036    ┆ 5036   ┆ 4643.0      ┆ 4481.0     ┆ 4423.0      │
# │ null_count ┆ 0.0        ┆ 1            ┆ 2        ┆ 6683      ┆ 2066                                ┆ 1956      ┆ 2113.0       ┆ 2119.0        ┆ 1647  ┆ 1647    ┆ 1647   ┆ 2040.0      ┆ 2202.0     ┆ 2260.0      │
# │ mean       ┆ 4.3601e7   ┆ null         ┆ null     ┆ null      ┆ null                                ┆ null      ┆ 78.051641    ┆ 210.994522    ┆ null  ┆ null    ┆ null   ┆ 1419.518199 ┆ -0.36532   ┆ 21.257744   │
# │ std        ┆ 2.7234e8   ┆ null         ┆ null     ┆ null      ┆ null                                ┆ null      ┆ 3.624647     ┆ 27.052877     ┆ null  ┆ null    ┆ null   ┆ 899.871852  ┆ 6.475244   ┆ 31.19442    │
# │ min        ┆ 2.0        ┆ A.C.         ┆ Abalde   ┆ null      ┆                                     ┆ Anla      ┆ 63.0         ┆ 133.0         ┆ 0     ┆ 0       ┆ 0      ┆ -22.0       ┆ -22.0      ┆ -22.0       │
# │ 25%        ┆ 56089.0    ┆ null         ┆ null     ┆ null      ┆ null                                ┆ null      ┆ 75.0         ┆ 190.0         ┆ null  ┆ null    ┆ null   ┆ -1.0        ┆ -1.0       ┆ -1.0        │
# │ 50%        ┆ 77925.0    ┆ null         ┆ null     ┆ null      ┆ null                                ┆ null      ┆ 78.0         ┆ 210.0         ┆ null  ┆ null    ┆ null   ┆ 1976.0      ┆ 1.0        ┆ 14.0        │
# │ 75%        ┆ 1.626168e6 ┆ null         ┆ null     ┆ null      ┆ null                                ┆ null      ┆ 81.0         ┆ 230.0         ┆ null  ┆ null    ┆ null   ┆ 1997.0      ┆ 2.0        ┆ 36.0        │
# │ max        ┆ 1.9669e9   ┆ de la Fuente ┆ Đurisic  ┆ null      ┆ Znicz Pruszkow                      ┆ Venezuela ┆ 91.0         ┆ 360.0         ┆ false ┆ false   ┆ false  ┆ 2025.0      ┆ 20.0       ┆ 221.0       │
# └────────────┴────────────┴──────────────┴──────────┴───────────┴─────────────────────────────────────┴───────────┴──────────────┴───────────────┴───────┴─────────┴────────┴─────────────┴────────────┴─────────────┘

# %%
lf.null_count().collect()
# Out:
# shape: (1, 14)
# ┌──────────┬───────────┬──────────┬───────────┬────────┬─────────┬──────────────┬───────────────┬───────┬─────────┬────────┬───────────┬────────────┬─────────────┐
# │ personId ┆ firstName ┆ lastName ┆ birthDate ┆ school ┆ country ┆ heightInches ┆ bodyWeightLbs ┆ guard ┆ forward ┆ center ┆ draftYear ┆ draftRound ┆ draftNumber │
# │ ---      ┆ ---       ┆ ---      ┆ ---       ┆ ---    ┆ ---     ┆ ---          ┆ ---           ┆ ---   ┆ ---     ┆ ---    ┆ ---       ┆ ---        ┆ ---         │
# │ u32      ┆ u32       ┆ u32      ┆ u32       ┆ u32    ┆ u32     ┆ u32          ┆ u32           ┆ u32   ┆ u32     ┆ u32    ┆ u32       ┆ u32        ┆ u32         │
# ╞══════════╪═══════════╪══════════╪═══════════╪════════╪═════════╪══════════════╪═══════════════╪═══════╪═════════╪════════╪═══════════╪════════════╪═════════════╡
# │ 0        ┆ 1         ┆ 2        ┆ 6683      ┆ 2066   ┆ 1956    ┆ 2113         ┆ 2119          ┆ 1647  ┆ 1647    ┆ 1647   ┆ 2040      ┆ 2202       ┆ 2260        │
# └──────────┴───────────┴──────────┴───────────┴────────┴─────────┴──────────────┴───────────────┴───────┴─────────┴────────┴───────────┴────────────┴─────────────┘

# %%
# Filtrar filas con al menos un nulo
filas_con_nulos = lf.filter(
    pl.any_horizontal(pl.all().is_null())
)

# Ejecutar y ver resultado (primeras 10 filas, por ejemplo)
print(filas_con_nulos.collect())
# Out:
# shape: (6_683, 14)
# ┌────────────┬──────────────┬──────────────┬───────────┬─────────────────┬─────────┬──────────────┬───────────────┬───────┬─────────┬────────┬───────────┬────────────┬─────────────┐
# │ personId   ┆ firstName    ┆ lastName     ┆ birthDate ┆ school          ┆ country ┆ heightInches ┆ bodyWeightLbs ┆ guard ┆ forward ┆ center ┆ draftYear ┆ draftRound ┆ draftNumber │
# │ ---        ┆ ---          ┆ ---          ┆ ---       ┆ ---             ┆ ---     ┆ ---          ┆ ---           ┆ ---   ┆ ---     ┆ ---    ┆ ---       ┆ ---        ┆ ---         │
# │ i64        ┆ str          ┆ str          ┆ str       ┆ str             ┆ str     ┆ i64          ┆ i64           ┆ str   ┆ str     ┆ str    ┆ i64       ┆ i64        ┆ i64         │
# ╞════════════╪══════════════╪══════════════╪═══════════╪═════════════════╪═════════╪══════════════╪═══════════════╪═══════╪═════════╪════════╪═══════════╪════════════╪═════════════╡
# │ 196294534  ┆ Alberto      ┆ Abalde       ┆ null      ┆ null            ┆ null    ┆ null         ┆ null          ┆ null  ┆ null    ┆ null   ┆ null      ┆ null       ┆ null        │
# │ 76001      ┆ Alaa         ┆ Abdelnaby    ┆ null      ┆ Duke            ┆ USA     ┆ 82           ┆ 240           ┆ 0     ┆ 1       ┆ 0      ┆ 1990      ┆ 1          ┆ 25          │
# │ 76002      ┆ Zaid         ┆ Abdul-Aziz   ┆ null      ┆ Iowa State      ┆ USA     ┆ 81           ┆ 235           ┆ 0     ┆ 0       ┆ 1      ┆ 1968      ┆ 1          ┆ 5           │
# │ 76003      ┆ Kareem       ┆ Abdul-Jabbar ┆ null      ┆ UCLA            ┆ USA     ┆ 86           ┆ 225           ┆ 0     ┆ 0       ┆ 1      ┆ 1969      ┆ 1          ┆ 1           │
# │ 51         ┆ Mahmoud      ┆ Abdul-Rauf   ┆ null      ┆ Louisiana State ┆ USA     ┆ 73           ┆ 162           ┆ 1     ┆ 0       ┆ 0      ┆ 1990      ┆ 1          ┆ 3           │
# │ …          ┆ …            ┆ …            ┆ …         ┆ …               ┆ …       ┆ …            ┆ …             ┆ …     ┆ …       ┆ …      ┆ …         ┆ …          ┆ …           │
# │ 1962936150 ┆ Maurillioh   ┆ de Rosa      ┆ null      ┆ null            ┆ null    ┆ null         ┆ null          ┆ null  ┆ null    ┆ null   ┆ null      ┆ null       ┆ null        │
# │ 560        ┆ de la Fuente ┆ de la Fuente ┆ null      ┆ null            ┆ null    ┆ null         ┆ null          ┆ null  ┆ null    ┆ null   ┆ null      ┆ null       ┆ null        │
# │ 1642365    ┆ Nikola       ┆ Đurisic      ┆ null      ┆ Mega Basket     ┆ Belgium ┆ 80           ┆ 214           ┆ 1     ┆ 0       ┆ 0      ┆ 2024      ┆ 2          ┆ 43          │
# │ 196294611  ┆ Olivinha     ┆ null         ┆ null      ┆ null            ┆ null    ┆ null         ┆ null          ┆ null  ┆ null    ┆ null   ┆ null      ┆ null       ┆ null        │
# │ 43217      ┆ Olivinha     ┆ null         ┆ null      ┆ null            ┆ null    ┆ null         ┆ null          ┆ null  ┆ null    ┆ null   ┆ null      ┆ null       ┆ null        │
# └────────────┴──────────────┴──────────────┴───────────┴─────────────────┴─────────┴──────────────┴───────────────┴───────┴─────────┴────────┴───────────┴────────────┴─────────────┘

# %% [markdown]
# ### Creamos el Dataframe para limpiarlo

# %%
df_players = lf.collect()
df_players.head(2)
# Out:
# shape: (2, 14)
# ┌───────────┬───────────┬───────────┬───────────┬────────┬─────────┬──────────────┬───────────────┬───────┬─────────┬────────┬───────────┬────────────┬─────────────┐
# │ personId  ┆ firstName ┆ lastName  ┆ birthDate ┆ school ┆ country ┆ heightInches ┆ bodyWeightLbs ┆ guard ┆ forward ┆ center ┆ draftYear ┆ draftRound ┆ draftNumber │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆ ---    ┆ ---     ┆ ---          ┆ ---           ┆ ---   ┆ ---     ┆ ---    ┆ ---       ┆ ---        ┆ ---         │
# │ i64       ┆ str       ┆ str       ┆ str       ┆ str    ┆ str     ┆ i64          ┆ i64           ┆ str   ┆ str     ┆ str    ┆ i64       ┆ i64        ┆ i64         │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪════════╪═════════╪══════════════╪═══════════════╪═══════╪═════════╪════════╪═══════════╪════════════╪═════════════╡
# │ 196294534 ┆ Alberto   ┆ Abalde    ┆ null      ┆ null   ┆ null    ┆ null         ┆ null          ┆ null  ┆ null    ┆ null   ┆ null      ┆ null       ┆ null        │
# │ 76001     ┆ Alaa      ┆ Abdelnaby ┆ null      ┆ Duke   ┆ USA     ┆ 82           ┆ 240           ┆ 0     ┆ 1       ┆ 0      ┆ 1990      ┆ 1          ┆ 25          │
# └───────────┴───────────┴───────────┴───────────┴────────┴─────────┴──────────────┴───────────────┴───────┴─────────┴────────┴───────────┴────────────┴─────────────┘
